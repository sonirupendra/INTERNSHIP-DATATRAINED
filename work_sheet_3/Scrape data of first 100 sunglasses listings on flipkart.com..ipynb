# %%
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')

# %%
#driver
drive=webdriver.Chrome("C:\web driver\chromedriver.exe")

# %%
#open flipkart
drive.get("https://www.flipkart.com/")

# %%
#serch sunglasses
serch_sunglasses = drive.find_element_by_class_name("_3704LK")
serch_sunglasses.send_keys("sunglasses")

# %%
#clicking
click= drive.find_element_by_class_name("L0Z3Pu")
click.click()

# %%
#createing empty list
brand = []
product_information=[]
price = []

# %%
brands = drive.find_elements_by_xpath("//div[@class='_2WkVRV']")
brands
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="7ac29467e1f1f63fc68e8ea273e6e8fa", element="c47e6996-7e6b-4866-bc35-cc8001085724")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7ac29467e1f1f63fc68e8ea273e6e8fa", element="5fa14093-9091-4178-82c9-1ada2182d6fa")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7ac29467e1f1f63fc68e8ea273e6e8fa", element="ace21972-265a-4885-aee4-e853671a5c59")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7ac29467e1f1f63fc68e8ea273e6e8fa", element="7f022615-550a-4efc-80d6-cb3675bb2e80")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7ac29467e1f1f63fc68e8ea273e6e8fa", element="716988ce-3068-45bb-86f5-90ad8f14a96f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7ac29467e1f1f63fc68e8ea273e6e8fa", element="bc607610-a9a2-4a09-af1a-25c0527c0ec6")>,
# ...

# %%
for i in brands:
    b=i.text
    brand.append(b)
brand
# Out:
# ['CRYSTAL CART',
#  'ROZZETTA CRAFT',
#  'Mi',
#  'SRPM',
#  'Fastrack',
#  'Fastrack',
#  'Elligator',
#  'ROZZETTA CRAFT',
#  'PIRASO',
#  'PIRASO',
#  'PIRASO',
#  'john jacobs',
#  'New Specs',
#  'ROZZETTA CRAFT',
#  'PIRASO',
#  'CRYSTAL CART',
#  'VINCENT CHASE',
#  'Fastrack',
#  'PIRASO',
#  'agera',
#  'Mi',
#  'ROZZETTA CRAFT',
#  'SUNBEE',
#  'VINCENT CHASE',
#  'Fastrack',
#  'PIRASO',
#  'VINCENT CHASE',
#  'CRYSTAL CART',
#  'United Colors of Benetton',
#  'United Colors of Benetton',
#  'ROYAL SON',
#  'ROZZETTA CRAFT',
#  'Fastrack',
#  'New Specs',
#  'SHAAH COLLECTIONS',
#  'AISLIN',
#  'SUNBEE',
#  'Elligator',
#  'GANSTA',
#  'ROZZETTA CRAFT']

# %%
len(brand)
# Out:
# 40

# %%
click2=drive.find_element_by_xpath("/html/body/div[1]/div/div[3]/div[1]/div[2]/div[12]/div/div/nav/a[11]")
click2.click()

# %%
brand2=drive.find_elements_by_xpath("//div[@class='_2WkVRV']")
brand2
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="7ac29467e1f1f63fc68e8ea273e6e8fa", element="8fcde68d-e715-4dbc-a65e-de758541f0ba")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7ac29467e1f1f63fc68e8ea273e6e8fa", element="86ba707a-9746-4d50-bc9a-6b39c37fbfc9")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7ac29467e1f1f63fc68e8ea273e6e8fa", element="d72cad89-8652-41cd-b03e-c063aea32b5b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7ac29467e1f1f63fc68e8ea273e6e8fa", element="104d3fcf-3509-4923-b5a3-3067e5ae3162")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7ac29467e1f1f63fc68e8ea273e6e8fa", element="62c78a5b-fc41-4089-980b-b996e9960f2c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7ac29467e1f1f63fc68e8ea273e6e8fa", element="3c976153-6128-4e64-b813-6dca1e1687c4")>,
# ...

# %%
for i in brand2:
    b=i.text
    brand.append(b)
brand
# Out:
# ['CRYSTAL CART',
#  'ROZZETTA CRAFT',
#  'Mi',
#  'SRPM',
#  'Fastrack',
#  'Fastrack',
#  'Elligator',
#  'ROZZETTA CRAFT',
#  'PIRASO',
#  'PIRASO',
#  'PIRASO',
#  'john jacobs',
#  'New Specs',
#  'ROZZETTA CRAFT',
#  'PIRASO',
#  'CRYSTAL CART',
#  'VINCENT CHASE',
#  'Fastrack',
#  'PIRASO',
#  'agera',
#  'Mi',
#  'ROZZETTA CRAFT',
#  'SUNBEE',
#  'VINCENT CHASE',
#  'Fastrack',
#  'PIRASO',
#  'VINCENT CHASE',
#  'CRYSTAL CART',
#  'United Colors of Benetton',
#  'United Colors of Benetton',
#  'ROYAL SON',
#  'ROZZETTA CRAFT',
#  'Fastrack',
#  'New Specs',
#  'SHAAH COLLECTIONS',
#  'AISLIN',
#  'SUNBEE',
#  'Elligator',
#  'GANSTA',
#  'ROZZETTA CRAFT',
#  'SRPM',
#  'ROZZETTA CRAFT',
#  'Urbanic',
#  'VINCENT CHASE',
#  'AISLIN',
#  'kingsunglasses',
#  'ROZZETTA CRAFT',
#  'AISLIN',
#  'Fastrack',
#  'ROZZETTA CRAFT',
#  'Lee Topper',
#  'ROYAL SON',
#  'Ray-Ban',
#  'GANSTA',
#  'SRPM',
#  'AISLIN',
#  'PHENOMENAL',
#  'ROYAL SON',
#  'PIRASO',
#  'VINCENT CHASE',
# ...

# %%
len(brand)
# Out:
# 80

# %%
click3=drive.find_element_by_xpath("/html/body/div[1]/div/div[3]/div[1]/div[2]/div[12]/div/div/nav/a[11]")
click3.click()

# %%
brand3= drive.find_elements_by_xpath("//div[@class='_2WkVRV']")
brand3[0:5]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="7ac29467e1f1f63fc68e8ea273e6e8fa", element="b158673a-bf56-496f-af6e-ac35577d1e29")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7ac29467e1f1f63fc68e8ea273e6e8fa", element="d48c7652-e9bf-498a-b906-bfa8ae779aaa")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7ac29467e1f1f63fc68e8ea273e6e8fa", element="a31ceed6-a657-4e8c-b56d-55eedd4fed13")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7ac29467e1f1f63fc68e8ea273e6e8fa", element="784e7d33-86d9-4e27-a2b8-501566abf220")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7ac29467e1f1f63fc68e8ea273e6e8fa", element="57a20f12-833a-4a93-8cca-770d0eeed246")>]

# %%
for i in brand3:
    b=i.text
    brand.append(b)
brand
# Out:
# ['CRYSTAL CART',
#  'ROZZETTA CRAFT',
#  'Mi',
#  'SRPM',
#  'Fastrack',
#  'Fastrack',
#  'Elligator',
#  'ROZZETTA CRAFT',
#  'PIRASO',
#  'PIRASO',
#  'PIRASO',
#  'john jacobs',
#  'New Specs',
#  'ROZZETTA CRAFT',
#  'PIRASO',
#  'CRYSTAL CART',
#  'VINCENT CHASE',
#  'Fastrack',
#  'PIRASO',
#  'agera',
#  'Mi',
#  'ROZZETTA CRAFT',
#  'SUNBEE',
#  'VINCENT CHASE',
#  'Fastrack',
#  'PIRASO',
#  'VINCENT CHASE',
#  'CRYSTAL CART',
#  'United Colors of Benetton',
#  'United Colors of Benetton',
#  'ROYAL SON',
#  'ROZZETTA CRAFT',
#  'Fastrack',
#  'New Specs',
#  'SHAAH COLLECTIONS',
#  'AISLIN',
#  'SUNBEE',
#  'Elligator',
#  'GANSTA',
#  'ROZZETTA CRAFT',
#  'SRPM',
#  'ROZZETTA CRAFT',
#  'Urbanic',
#  'VINCENT CHASE',
#  'AISLIN',
#  'kingsunglasses',
#  'ROZZETTA CRAFT',
#  'AISLIN',
#  'Fastrack',
#  'ROZZETTA CRAFT',
#  'Lee Topper',
#  'ROYAL SON',
#  'Ray-Ban',
#  'GANSTA',
#  'SRPM',
#  'AISLIN',
#  'PHENOMENAL',
#  'ROYAL SON',
#  'PIRASO',
#  'VINCENT CHASE',
# ...

# %%
len(brand)
# Out:
# 120

# %%
prod1= drive.find_elements_by_xpath("//a[@class='IRpwTa']")
prod1
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="7ac29467e1f1f63fc68e8ea273e6e8fa", element="a10aa002-9c7a-448f-b36c-a8984cab2945")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7ac29467e1f1f63fc68e8ea273e6e8fa", element="84fbaf38-1ebe-4384-acb1-285ce2d7c96b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7ac29467e1f1f63fc68e8ea273e6e8fa", element="fb9ff794-69ff-405d-947b-266f7005afa1")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7ac29467e1f1f63fc68e8ea273e6e8fa", element="f6dba162-02e5-46e1-a555-9bcc4c2fae79")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7ac29467e1f1f63fc68e8ea273e6e8fa", element="f380a19d-f51d-4260-8362-a0b10f23960c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7ac29467e1f1f63fc68e8ea273e6e8fa", element="b06466e4-8af1-426f-ac9a-9e58dc851dc6")>,
# ...

# %%
for i in prod1:
    p=i.text
    product_information.append(p)
product_information
# Out:
# ['UV Protection Oval, Aviator Sunglasses (60)',
#  'UV Protection, Night Vision, Riding Glasses Sports Sung...',
#  'Polarized Aviator Sunglasses (Free Size)',
#  'UV Protection Wayfarer Sunglasses (50)',
#  'UV Protection Rectangular Sunglasses (Free Size)',
#  'UV Protection Wayfarer Sunglasses (Free Size)',
#  'UV Protection Round Sunglasses (54)',
#  'UV Protection, Gradient Butterfly, Over-sized Sunglasse...',
#  'UV Protection Aviator Sunglasses (54)',
#  'UV Protection Aviator Sunglasses (58)',
#  'Polarized, Riding Glasses Sports, Wrap-around Sunglasse...',
#  'UV Protection Oval, Aviator Sunglasses (62)',
#  'UV Protection Aviator Sunglasses (54)',
#  'UV Protection Rectangular Sunglasses (Free Size)',
#  'UV Protection Rectangular Sunglasses (52)',
#  'Polarized, Riding Glasses Sports, Wrap-around Sunglasse...',
#  'by Lenskart Polarized, UV Protection Cat-eye Sunglasses...',
#  'Gradient, UV Protection Wayfarer Sunglasses (Free Size)',
# ...

# %%
click4=drive.find_element_by_xpath("/html/body/div[1]/div/div[3]/div[1]/div[2]/div[12]/div/div/nav/a[11]")
click4.click()

# %%
prod2 = drive.find_elements_by_xpath("//a[@class='IRpwTa']")
prod2
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="7ac29467e1f1f63fc68e8ea273e6e8fa", element="c4635f1d-3951-4ea3-86af-d72511e54dbd")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7ac29467e1f1f63fc68e8ea273e6e8fa", element="a7943444-5ab8-4dbb-88af-ca28fe4907ee")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7ac29467e1f1f63fc68e8ea273e6e8fa", element="7b542501-9a8b-470f-8587-04aa879caea7")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7ac29467e1f1f63fc68e8ea273e6e8fa", element="0fbb9d68-bc00-40b8-b81f-66f66feb5eee")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7ac29467e1f1f63fc68e8ea273e6e8fa", element="6b6a934d-1dca-4201-bc2e-2a9ea3b541a7")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7ac29467e1f1f63fc68e8ea273e6e8fa", element="f7c2c593-67e8-494b-ae56-0c37e3a8fa54")>,
# ...

# %%
for i in prod2:
    p=i.text
    product_information.append(p)
product_information
# Out:
# ['UV Protection Oval, Aviator Sunglasses (60)',
#  'UV Protection, Night Vision, Riding Glasses Sports Sung...',
#  'Polarized Aviator Sunglasses (Free Size)',
#  'UV Protection Wayfarer Sunglasses (50)',
#  'UV Protection Rectangular Sunglasses (Free Size)',
#  'UV Protection Wayfarer Sunglasses (Free Size)',
#  'UV Protection Round Sunglasses (54)',
#  'UV Protection, Gradient Butterfly, Over-sized Sunglasse...',
#  'UV Protection Aviator Sunglasses (54)',
#  'UV Protection Aviator Sunglasses (58)',
#  'Polarized, Riding Glasses Sports, Wrap-around Sunglasse...',
#  'UV Protection Oval, Aviator Sunglasses (62)',
#  'UV Protection Aviator Sunglasses (54)',
#  'UV Protection Rectangular Sunglasses (Free Size)',
#  'UV Protection Rectangular Sunglasses (52)',
#  'Polarized, Riding Glasses Sports, Wrap-around Sunglasse...',
#  'by Lenskart Polarized, UV Protection Cat-eye Sunglasses...',
#  'Gradient, UV Protection Wayfarer Sunglasses (Free Size)',
# ...

# %%
len(product_information)
# Out:
# 80

# %%
prod3=drive.find_elements_by_xpath("//a[@class='IRpwTa']")
prod3[0:5]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="7ac29467e1f1f63fc68e8ea273e6e8fa", element="e20fe6ee-2a96-44b5-a30e-31e40e2d3c9f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7ac29467e1f1f63fc68e8ea273e6e8fa", element="ab11efe0-b52f-4061-890a-edd9d8445e25")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7ac29467e1f1f63fc68e8ea273e6e8fa", element="8281c295-571d-4eee-b573-e1eb0b3fba05")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7ac29467e1f1f63fc68e8ea273e6e8fa", element="63010d5c-0cdf-40b8-96c0-739b52060b87")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7ac29467e1f1f63fc68e8ea273e6e8fa", element="f98a00ab-c5bc-4666-b4fe-7a3937db19ec")>]

# %%
for i in prod3:
    p=i.text
    product_information.append(p)
product_information
# Out:
# ['UV Protection Oval, Aviator Sunglasses (60)',
#  'UV Protection, Night Vision, Riding Glasses Sports Sung...',
#  'Polarized Aviator Sunglasses (Free Size)',
#  'UV Protection Wayfarer Sunglasses (50)',
#  'UV Protection Rectangular Sunglasses (Free Size)',
#  'UV Protection Wayfarer Sunglasses (Free Size)',
#  'UV Protection Round Sunglasses (54)',
#  'UV Protection, Gradient Butterfly, Over-sized Sunglasse...',
#  'UV Protection Aviator Sunglasses (54)',
#  'UV Protection Aviator Sunglasses (58)',
#  'Polarized, Riding Glasses Sports, Wrap-around Sunglasse...',
#  'UV Protection Oval, Aviator Sunglasses (62)',
#  'UV Protection Aviator Sunglasses (54)',
#  'UV Protection Rectangular Sunglasses (Free Size)',
#  'UV Protection Rectangular Sunglasses (52)',
#  'Polarized, Riding Glasses Sports, Wrap-around Sunglasse...',
#  'by Lenskart Polarized, UV Protection Cat-eye Sunglasses...',
#  'Gradient, UV Protection Wayfarer Sunglasses (Free Size)',
# ...

# %%
len(product_information)
# Out:
# 120

# %%
price1 = drive.find_elements_by_xpath("//div[@class='_30jeq3']")
price1
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="7ac29467e1f1f63fc68e8ea273e6e8fa", element="41e34e6d-e04c-4266-a604-2367d13196e3")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7ac29467e1f1f63fc68e8ea273e6e8fa", element="c8098eed-9fed-442b-8954-9d7e29aaaa81")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7ac29467e1f1f63fc68e8ea273e6e8fa", element="22fae4e2-2858-4eb9-8851-ce6a2b0883e3")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7ac29467e1f1f63fc68e8ea273e6e8fa", element="fbcd77ab-9c1f-45c2-8891-20112c5a7bba")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7ac29467e1f1f63fc68e8ea273e6e8fa", element="b877b07a-b695-4e08-880f-48a41abac9b1")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7ac29467e1f1f63fc68e8ea273e6e8fa", element="40d170b2-b887-488f-8d7c-00465c818af7")>,
# ...

# %%
for i in price1:
    p=i.text
    price.append(p)
price
# Out:
# ['₹3,325',
#  '₹501',
#  '₹649',
#  '₹199',
#  '₹639',
#  '₹699',
#  '₹280',
#  '₹479',
#  '₹199',
#  '₹319',
#  '₹449',
#  '₹3,150',
#  '₹199',
#  '₹264',
#  '₹272',
#  '₹242',
#  '₹719',
#  '₹599',
#  '₹599',
#  '₹3,600',
#  '₹219',
#  '₹314',
#  '₹283',
#  '₹2,250',
#  '₹899',
#  '₹410',
#  '₹669',
#  '₹3,600',
#  '₹719',
#  '₹739',
#  '₹531',
#  '₹2,850',
#  '₹699',
#  '₹299',
#  '₹195',
#  '₹3,150',
#  '₹195',
#  '₹259',
#  '₹207',
#  '₹3,150']

# %%
click5 = drive.find_element_by_xpath("/html/body/div[1]/div/div[3]/div[1]/div[2]/div[12]/div/div/nav/a[11]")
click5.click()

# %%
price2 = drive.find_elements_by_xpath("//div[@class='_30jeq3']")
price2
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="7ac29467e1f1f63fc68e8ea273e6e8fa", element="81bb199e-fa28-42f6-8564-1760915687c7")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7ac29467e1f1f63fc68e8ea273e6e8fa", element="aa125b50-c584-49d1-89df-decf11105a1b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7ac29467e1f1f63fc68e8ea273e6e8fa", element="15355f94-a87f-4ea6-81fb-7a3e59a10842")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7ac29467e1f1f63fc68e8ea273e6e8fa", element="ab80f36b-64c7-4260-bd0e-a49beb62d867")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7ac29467e1f1f63fc68e8ea273e6e8fa", element="a3e7cc8c-2139-4712-908b-63033dfeba6a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7ac29467e1f1f63fc68e8ea273e6e8fa", element="3b03e1f7-5b0b-4dcb-9524-151d6efc57d5")>,
# ...

# %%
for i in price2:
    p=i.text
    price.append(p)
price
# Out:
# ['₹3,325',
#  '₹501',
#  '₹649',
#  '₹199',
#  '₹639',
#  '₹699',
#  '₹280',
#  '₹479',
#  '₹199',
#  '₹319',
#  '₹449',
#  '₹3,150',
#  '₹199',
#  '₹264',
#  '₹272',
#  '₹242',
#  '₹719',
#  '₹599',
#  '₹599',
#  '₹3,600',
#  '₹219',
#  '₹314',
#  '₹283',
#  '₹2,250',
#  '₹899',
#  '₹410',
#  '₹669',
#  '₹3,600',
#  '₹719',
#  '₹739',
#  '₹531',
#  '₹2,850',
#  '₹699',
#  '₹299',
#  '₹195',
#  '₹3,150',
#  '₹195',
#  '₹259',
#  '₹207',
#  '₹3,150',
#  '₹213',
#  '₹449',
#  '₹681',
#  '₹375',
#  '₹699',
#  '₹359',
#  '₹299',
#  '₹9,599',
#  '₹279',
#  '₹3,639',
#  '₹719',
#  '₹9,599',
#  '₹759',
#  '₹207',
#  '₹332',
#  '₹288',
#  '₹307',
#  '₹531',
#  '₹629',
#  '₹324',
#  '₹203',
#  '₹999',
#  '₹279',
#  '₹398',
#  '₹307',
#  '₹410',
#  '₹259',
#  '₹5,039',
#  '₹720',
#  '₹449',
#  '₹269',
#  '₹359',
#  '₹359',
#  '₹160',
#  '₹274',
#  '₹359',
#  '₹415',
#  '₹269',
#  '₹221',
#  '₹4,269']

# %%
price3 = drive.find_elements_by_xpath("//div[@class='_30jeq3']")

price3[0:5]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="7ac29467e1f1f63fc68e8ea273e6e8fa", element="cff7671f-0ef5-46c9-90b0-e43c3b2ad499")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7ac29467e1f1f63fc68e8ea273e6e8fa", element="d3763327-644f-48bd-9830-d735c4fb3724")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7ac29467e1f1f63fc68e8ea273e6e8fa", element="2427a243-b52f-485f-8fdc-cad8265ad93b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7ac29467e1f1f63fc68e8ea273e6e8fa", element="25269de8-63b4-4ec1-8326-214a974ed4a4")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="7ac29467e1f1f63fc68e8ea273e6e8fa", element="10361fd8-6141-407e-b7fd-92604691a4d0")>]

# %%
for i in price3:
    p=i.text
    price.append(p)
price
# Out:
# ['₹3,325',
#  '₹501',
#  '₹649',
#  '₹199',
#  '₹639',
#  '₹699',
#  '₹280',
#  '₹479',
#  '₹199',
#  '₹319',
#  '₹449',
#  '₹3,150',
#  '₹199',
#  '₹264',
#  '₹272',
#  '₹242',
#  '₹719',
#  '₹599',
#  '₹599',
#  '₹3,600',
#  '₹219',
#  '₹314',
#  '₹283',
#  '₹2,250',
#  '₹899',
#  '₹410',
#  '₹669',
#  '₹3,600',
#  '₹719',
#  '₹739',
#  '₹531',
#  '₹2,850',
#  '₹699',
#  '₹299',
#  '₹195',
#  '₹3,150',
#  '₹195',
#  '₹259',
#  '₹207',
#  '₹3,150',
#  '₹213',
#  '₹449',
#  '₹681',
#  '₹375',
#  '₹699',
#  '₹359',
#  '₹299',
#  '₹9,599',
#  '₹279',
#  '₹3,639',
#  '₹719',
#  '₹9,599',
#  '₹759',
#  '₹207',
#  '₹332',
#  '₹288',
#  '₹307',
#  '₹531',
#  '₹629',
#  '₹324',
#  '₹203',
#  '₹999',
#  '₹279',
#  '₹398',
#  '₹307',
#  '₹410',
#  '₹259',
#  '₹5,039',
#  '₹720',
#  '₹449',
#  '₹269',
#  '₹359',
#  '₹359',
#  '₹160',
#  '₹274',
#  '₹359',
#  '₹415',
#  '₹269',
#  '₹221',
#  '₹4,269',
#  '₹217',
#  '₹449',
#  '₹618',
#  '₹639',
#  '₹499',
#  '₹293',
#  '₹1,529',
#  '₹639',
# ...

# %%
len(price)
# Out:
# 120

# %%
df = pd.DataFrame({"Brand":brand,"Information":product_information,"Price":price})

# %%
df.head(20)
# Out:
#              Brand                                        Information   Price
# 0     CRYSTAL CART        UV Protection Oval, Aviator Sunglasses (60)  ₹3,325
# 1   ROZZETTA CRAFT  UV Protection, Night Vision, Riding Glasses Sp...    ₹501
# 2               Mi           Polarized Aviator Sunglasses (Free Size)    ₹649
# 3             SRPM             UV Protection Wayfarer Sunglasses (50)    ₹199
# 4         Fastrack   UV Protection Rectangular Sunglasses (Free Size)    ₹639
# 5         Fastrack      UV Protection Wayfarer Sunglasses (Free Size)    ₹699
# 6        Elligator                UV Protection Round Sunglasses (54)    ₹280
# 7   ROZZETTA CRAFT  UV Protection, Gradient Butterfly, Over-sized ...    ₹479
# 8           PIRASO              UV Protection Aviator Sunglasses (54)    ₹199
# 9           PIRASO              UV Protection Aviator Sunglasses (58)    ₹319
# 10          PIRASO  Polarized, Riding Glasses Sports, Wrap-around ...    ₹449
# ...
